# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# df.read("/kaggle/input/ipl-auction-2023/iplauction2023.csv")

# %%
import panda as pd
df=pd.read_csv("/kaggle/input/ipl-auction/iplauction2023.csv")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-411c84da721c> in <cell line: 1>()
# ----> 1 import panda as pd
#       2 df=pd.read_csv("/kaggle/input/ipl-auction/iplauction2023.csv")
#
# ModuleNotFoundError: No module named 'panda'

# %%
df=pd.read_csv("/kaggle/input/ipl-auction/iplauction2023.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-5e6e3973ce10> in <cell line: 1>()
# ----> 1 df=pd.read_csv("/kaggle/input/ipl-auction/iplauction2023.csv")
#
# NameError: name 'pd' is not defined

# %% [raw]
# import panda as pd

# %%
df=pd.read_csv("/kaggle/input/ipl-auction/iplauction2023.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-5e6e3973ce10> in <cell line: 1>()
# ----> 1 df=pd.read_csv("/kaggle/input/ipl-auction/iplauction2023.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df=pd.read_csv("/kaggle/input/ipl-auction/iplauction2023.csv")

# %%
df.head()
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                   NaN
# 1        Ekant Sen       Batter         India                  20.0
# 2    Wayne Parnell   Allrounder  South Africa                  75.0
# 3  Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4         Joe Root       Batter       England                 100.0
#
#    final price (in lacs) franchise    status
# 0                   20.0       KKR  RETAINED
# 1                    NaN       NaN    UNSOLD
# 2                    NaN       NaN    UNSOLD
# 3                  150.0       KKR      SOLD
# 4                  100.0        RR      SOLD

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   151 non-null    float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.0+ KB

# %%
df.isnull().sum()
# Out:
# name                       0
# player style               0
# nationality                0
# base price (in lacs)     158
# final price (in lacs)     71
# franchise                 71
# status                     0
# dtype: int64

# %%
df['franchise'].unique()
# Out:
# array(['KKR', nan, 'RR', 'SRH', 'MI', 'LSG', 'DC', 'PBKS', 'CSK', 'RCB',
#        'GT'], dtype=object)

# %%
fig = df['franchise'].value_counts().plot.bar()
fig.set_title('Purchasing Team')
# Out:
# Text(0.5, 1.0, 'Purchasing Team')

# %%
df['franchise'].mode()
# Out:
# 0    CSK
# 1     GT
# 2    LSG
# 3    RCB
# 4     RR
# 5    SRH
# Name: franchise, dtype: object

# %%
import numpy as np

# %%
franchise_proportion = df['franchise'].value_counts(normalize = True)

# %%
df['franchise'] = df['franchise'].apply(
    lambda x: np.random.choice(franchise_proportion.index, p=franchise_proportion.values)
    if pd.isnull(x) else x
)

# %%
plot.bar('franchise')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b918807e9b31> in <cell line: 1>()
# ----> 1 plot.bar('franchise')
#
# NameError: name 'plot' is not defined

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plot.bar('franchise')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-b918807e9b31> in <cell line: 1>()
# ----> 1 plot.bar('franchise')
#
# NameError: name 'plot' is not defined

# %%
plt.bar('franchise')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-ce262985a438> in <cell line: 1>()
# ----> 1 plt.bar('franchise')
#
# TypeError: bar() missing 1 required positional argument: 'height'

# %%
df['franchise'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='franchise'>

# %%
df.isnull().sum()
# Out:
# name                       0
# player style               0
# nationality                0
# base price (in lacs)     158
# final price (in lacs)     71
# franchise                 71
# status                     0
# dtype: int64

# %%
mode = df['franchise'].mode()[0]

# %%
df['franchise'] = df['franchise'].fillna(mode)

# %%
df['franchise'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='franchise'>

# %%
df.isnull().sum()
# Out:
# name                       0
# player style               0
# nationality                0
# base price (in lacs)     158
# final price (in lacs)     71
# franchise                  0
# status                     0
# dtype: int64
